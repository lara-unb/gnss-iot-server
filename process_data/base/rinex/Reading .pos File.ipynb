# %%
import os
import pandas as pd

# %%
#Tratamento da Solução da Base
fileBase = "~/GNSS/gnss-iot-server/DATA/EXP1/BASE/RNXRTKP/sol1_201911091804.pos"
data = pd.read_csv(fileBase, sep="\s+", skiprows=9)
data.columns = ['GPS Week', 'GPST', 'latitude(deg)', 'longitude(deg)', 'height(m)', 'Q', 'ns',
                'sdn(m)', 'sde(m)', 'sdu(m)', 'sdne(m)', 'sdeu(m)', 'sdun(m)', 'age(s)',
                'ratio']
data.head()
# Out:
#    GPS Week      GPST  latitude(deg)  longitude(deg)  height(m)  Q  ns  \
# 0      2078  583499.0     -15.765921      -47.872176  1054.7010  5  12
# 1      2078  583500.0     -15.765922      -47.872178  1054.1277  5  12
# 2      2078  583501.0     -15.765924      -47.872177  1054.6422  5  12
# 3      2078  583502.0     -15.765926      -47.872178  1054.6129  5  12
# 4      2078  583503.0     -15.765927      -47.872180  1054.4976  5  12
#
#    sdn(m)  sde(m)  sdu(m)  sdne(m)  sdeu(m)  sdun(m)  age(s)  ratio
# 0  3.4873  3.9729  9.6846   1.5830  -2.1848  -0.6321     0.0    0.0
# 1  3.4872  3.9728  9.6832   1.5830  -2.1830  -0.6332     0.0    0.0
# 2  3.4872  3.9727  9.6819   1.5829  -2.1811  -0.6343     0.0    0.0
# 3  3.4871  3.9726  9.6805   1.5829  -2.1793  -0.6354     0.0    0.0
# 4  3.4871  3.9725  9.6792   1.5829  -2.1774  -0.6366     0.0    0.0
